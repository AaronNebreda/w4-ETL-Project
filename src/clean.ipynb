# %%
import pandas as pd
import numpy as np


imdb=pd.read_csv('../data/imdb.csv')

cast = pd.read_csv('../data/cast.csv')

films=pd.read_csv('../data/mcu_box_office.csv')

pers=pd.read_csv('../data/character.csv')

# %%
imdb.head()
# Out:
#                                  peli rating  \
# 0                            Iron Man    7,9
# 1                 The Incredible Hulk    6,6
# 2                          Iron Man 2    6,9
# 3                                Thor    6,3
# 4  Captain America: The First Avenger    6,9
#
#                                          link_imagen  \
# 0  https://www.imdb.com/title/tt0371746/mediaview...
# 1  https://www.imdb.com/title/tt0800080/mediaview...
# 2  https://www.imdb.com/title/tt1228705/mediaview...
# 3  https://www.imdb.com/title/tt10648342/mediavie...
# 4  https://www.imdb.com/title/tt0458339/mediaview...
#
#                                         link_trailer
# 0  https://www.imdb.com/title/tt0371746/mediaview...
# 1  https://www.imdb.com/title/tt0800080/mediaview...
# 2  https://www.imdb.com/title/tt1228705/mediaview...
# 3  https://www.imdb.com/title/tt10648342/mediavie...
# 4  https://www.imdb.com/title/tt0458339/mediaview...

# %%
cast.head()
# Out:
#    Unnamed: 0      peli                                   cast  \
# 0           0  Iron Man    ['Robert Downey Jr.', 'Tony Stark']
# 1           0  Iron Man    ['Gwyneth Paltrow', 'Pepper Potts']
# 2           0  Iron Man          ['Terrence Howard', 'Rhodey']
# 3           0  Iron Man      ['Jeff Bridges', 'Obadiah Stane']
# 4           0  Iron Man  ['Leslie Bibb', 'Christine Everhart']
#
#                actor           personaje
# 0  Robert Downey Jr.          Tony Stark
# 1    Gwyneth Paltrow        Pepper Potts
# 2    Terrence Howard              Rhodey
# 3       Jeff Bridges       Obadiah Stane
# 4        Leslie Bibb  Christine Everhart

# %%
films.head()
# Out:
#                           movie_title  mcu_phase release_date  tomato_meter  \
# 0                            Iron Man          1     5/2/2008            94
# 1                 The Incredible Hulk          1    6/13/2008            67
# 2                          Iron Man 2          1     5/7/2010            72
# 3                                Thor          1     5/6/2011            77
# 4  Captain America: The First Avenger          1    7/22/2011            79
#
#    audience_score  movie_duration production_budget opening_weekend  \
# 0              91             126       186,000,000     102,118,668
# 1              70             112       137,500,000      55,414,050
# 2              71             124       170,000,000     128,122,480
# 3              76             113       150,000,000      65,723,338
# 4              75             124       140,000,000      65,058,524
#
#   domestic_box_office worldwide_box_office
# 0         318,604,126          585,171,547
# ...

# %%
pers.head()
# Out:
#                                   name                ID               ALIGN  \
# 0            Spider-Man (Peter Parker)   Secret Identity     Good Characters
# 1      Captain America (Steven Rogers)   Public Identity     Good Characters
# 2  Wolverine (James \"Logan\" Howlett)   Public Identity  Neutral Characters
# 3    Iron Man (Anthony \"Tony\" Stark)   Public Identity     Good Characters
# 4                  Thor (Thor Odinson)  No Dual Identity     Good Characters
#
#           EYE        HAIR              SEX  GSM              ALIVE  \
# 0  Hazel Eyes  Brown Hair  Male Characters  NaN  Living Characters
# 1   Blue Eyes  White Hair  Male Characters  NaN  Living Characters
# 2   Blue Eyes  Black Hair  Male Characters  NaN  Living Characters
# 3   Blue Eyes  Black Hair  Male Characters  NaN  Living Characters
# 4   Blue Eyes  Blond Hair  Male Characters  NaN  Living Characters
#
#    APPEARANCES FIRST APPEARANCE    Year
# 0       4043.0           Aug-62  1962.0
# ...
