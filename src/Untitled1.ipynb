# %%
import pandas as pd
import numpy as np
import re

pd.set_option('display.max_columns', None)   # mostrar todas las columnas del df
pd.set_option('display.max_rows', None)   # mostrar todas las filas del df

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('../data/marvel_clean.csv')

# %%
df.sort_values(by= ['Title'])
# Out:
#                                         Title  \
# 37                                    Ant-Man
# 51                       Ant-Man and the Wasp
# 36                    Avengers: Age of Ultron
# 55                          Avengers: Endgame
# 49                     Avengers: Infinity War
# 35                                 Big Hero 6
# 48                              Black Panther
# 59                                Black Widow
# 1                                       Blade
# 3                                    Blade II
# 10                             Blade: Trinity
# 40                 Captain America: Civil War
# 24         Captain America: The First Avenger
# 31        Captain America: The Winter Soldier
# 54                             Captain Marvel
# 5                                   Daredevil
# 56                               Dark Phoenix
# 39                                   Deadpool
# 50                                 Deadpool 2
# 42                             Doctor Strange
# 11                                    Elektra
# 62                                   Eternals
# 12                             Fantastic Four
# 38                             Fantastic Four
# 16  Fantastic Four: Rise of the Silver Surfer
# 14                                Ghost Rider
# 25           Ghost Rider: Spirit of Vengeance
# 34                    Guardians of the Galaxy
# 44             Guardians of the Galaxy Vol. 2
# 0                             Howard the Duck
# 7                                        Hulk
# 46                                   Inhumans
# 17                                   Iron Man
# 21                                 Iron Man 2
# 28                                 Iron Man 3
# 43                                      Logan
# 19                         Punisher: War Zone
# 60  Shang-Chi and the Legend of the Ten Rings
# 4                                  Spider-Man
# 9                                Spider-Man 2
# 15                               Spider-Man 3
# 57                  Spider-Man: Far From Home
# 45                     Spider-Man: Homecoming
# 53          Spider-Man: Into the Spider-Verse
# 63                    Spider-Man: No Way Home
# 27                     The Amazing Spider-Man
# 32                   The Amazing Spider-Man 2
# 26                               The Avengers
# 18                        The Incredible Hulk
# 58                            The New Mutants
# 8                                The Punisher
# 29                              The Wolverine
# 22                                       Thor
# 47                             Thor: Ragnarok
# 30                       Thor: The Dark World
# 52                                      Venom
# 61                Venom: Let There Be Carnage
# 2                                       X-Men
# 20                   X-Men Origins: Wolverine
# 41                          X-Men: Apocalypse
# 33                 X-Men: Days of Future Past
# 23                         X-Men: First Class
# 13                      X-Men: The Last Stand
# 6                                          X2
#
#                             Distributor        ReleaseDateUS     Budget  \
# 37  Walt Disney Studios Motion Pictures  2015-07-17 00:00:00  130000000
# 51  Walt Disney Studios Motion Pictures  2018-07-06 00:00:00  162000000
# 36  Walt Disney Studios Motion Pictures  2015-05-01 00:00:00  250000000
# 55  Walt Disney Studios Motion Pictures  2019-04-26 00:00:00  356000000
# 49  Walt Disney Studios Motion Pictures  2018-04-27 00:00:00  316000000
# 35  Walt Disney Studios Motion Pictures  2014-11-07 00:00:00  165000000
# 48  Walt Disney Studios Motion Pictures  2018-02-16 00:00:00  200000000
# 59  Walt Disney Studios Motion Pictures  2021-07-09 00:00:00  200000000
# 1                       New Line Cinema  1998-08-21 00:00:00   45000000
# 3                       New Line Cinema  2002-03-22 00:00:00   54000000
# 2                     54471475     157299717         139039810   296339527
# 20                    85058003     179883157         193179707   373062864
# 41                    65769562     155442489         388491616   543934105
# 33                    90823660     233921534         513941241   747862775
# 23                    55101604     146408305         207215819   353624124
# 13                   102750665     234362462         224997093   459359555
# 6                     85558731     214949694         192761855   407711549

# %%
df1=pd.read_csv('../data/mcu_box_office.csv')

# %%
df1
# Out:
#                                   movie_title  mcu_phase release_date  \
# 0                                    Iron Man          1     5/2/2008
# 1                         The Incredible Hulk          1    6/13/2008
# 2                                  Iron Man 2          1     5/7/2010
# 3                                        Thor          1     5/6/2011
# 4          Captain America: The First Avenger          1    7/22/2011
# 5                                The Avengers          1     5/4/2012
# 6                                  Iron Man 3          2     5/3/2013
# 7                        Thor: The Dark World          2    11/8/2013
# 8         Captain America: The Winter Soldier          2     4/4/2014
# 9                     Guardians of the Galaxy          2     8/1/2014
# 10                    Avengers: Age of Ultron          2     5/1/2015
# 11                                    Ant-Man          2    7/17/2015
# 12                 Captain America: Civil War          3     5/6/2016
# 13                             Doctor Strange          3    11/4/2016
# 14             Guardians of the Galaxy Vol. 2          3     5/5/2017
# 15                     Spider-Man: Homecoming          3     7/7/2017
# 16                             Thor: Ragnarok          3    11/3/2017
# 17                              Black Panther          3    2/16/2018
# 18                     Avengers: Infinity War          3    4/27/2018
# 19                       Ant-Man and the Wasp          3     7/6/2018
# 20                             Captain Marvel          3     3/8/2019
# 21                         Avengers: End Game          3    4/26/2019
# 22                  Spider-Man: Far From Home          3     7/2/2019
# 23                                Black Widow          4     7/9/2021
# 24  Shang-Chi and the Legend of the Ten Rings          4     9/3/2021
# 25                                   Eternals          4    11/5/2021
# 26                    Spider-Man: No Way Home          4   12/17/2021
#
#     tomato_meter  audience_score  movie_duration production_budget  \
# 0             94              91             126       186,000,000
# 1             67              70             112       137,500,000
# 2             72              71             124       170,000,000
# 3             77              76             113       150,000,000
# 4             79              75             124       140,000,000
# 5             91              91             143       225,000,000
# 6             79              78             130       200,000,000
# 7             66              75             111       150,000,000
# 8             90              92             135       170,000,000
# 9             92              92             121       170,000,000
# 10            76              83             141       365,000,000
# 11            83              85             117       130,000,000
# 12            90              89             146       250,000,000
# 13            89              86             115       165,000,000
# 14            85              87             135       200,000,000
# 15            92              87             133       175,000,000
# 16            93              87             130       180,000,000
# 17            96              79             134       200,000,000
# 18            85              91             149       300,000,000
# 19            87              81             118       130,000,000
# 20            79              45             124       175,000,000
# 21            94              90             181       400,000,000
# 22            90              95             129       160,000,000
# 23            79              91             133       200,000,000
# 24            91              98             133       150,000,000
# 25            47              78             157       200,000,000
# 26            93              98             148       200,000,000
#
#    opening_weekend domestic_box_office worldwide_box_office
# 0      102,118,668         318,604,126          585,171,547
# 1       55,414,050         134,806,913          265,573,859
# 2      128,122,480         312,433,331          621,156,389
# 3       65,723,338         181,030,624          449,326,618
# 4       65,058,524         176,654,505          370,569,776
# 5      207,438,708         623,357,910        1,515,100,211
# 6      174,144,585         408,992,272        1,215,392,272
# 7       85,737,841         206,362,140          644,602,516
# 8       95,023,721         259,746,958          714,401,889
# 9       94,320,883         333,714,112          770,882,395
# 10     191,271,109         459,005,868        1,395,316,979
# 11      57,225,526         180,202,163          518,858,449
# 12     179,139,142         408,084,349        1,151,918,521
# 13      85,058,311         232,641,920          676,354,481
# 14     146,510,104         389,813,101          869,113,101
# 15     117,027,503         334,201,140          878,346,440
# 16     122,744,989         315,058,289          850,482,778
# 17     202,003,951         700,059,566        1,336,494,321
# 18     257,698,183         678,815,482        2,048,359,754
# 19      75,812,205         216,648,740          623,144,660
# 20     153,433,423         426,829,839        1,129,727,388
# 21     357,115,007         858,373,000        2,797,800,564
# 22      92,579,212         390,532,085        1,132,532,832
# 23      80,366,312         183,651,655          379,751,655
# 24      75,388,688         224,543,292          432,243,292
# 25      71,297,219         164,870,264          402,064,929
# 26     260,138,569         803,975,784        1,891,108,035

# %%
df1.describe().T
# Out:
#                 count        mean        std    min    25%    50%    75%  \
# mcu_phase        27.0    2.481481   1.014145    1.0    2.0    3.0    3.0
# tomato_meter     27.0   83.555556  11.112479   47.0   79.0   87.0   91.5
# audience_score   27.0   83.740741  11.002072   45.0   78.0   87.0   91.0
# movie_duration   27.0  131.925926  15.531422  111.0  122.5  130.0  138.0
#
#                   max
# mcu_phase         4.0
# tomato_meter     96.0
# audience_score   98.0
# movie_duration  181.0

# %%
titulos = df1.movie_title.to_list()

# %%
titulos
# Out:
# ['Iron Man',
#  'The Incredible Hulk',
#  'Iron Man 2',
#  'Thor',
#  'Captain America: The First Avenger',
#  'The Avengers',
#  'Iron Man 3',
#  'Thor: The Dark World',
#  'Captain America: The Winter Soldier',
#  'Guardians of the Galaxy',
#  'Avengers: Age of Ultron',
#  'Ant-Man',
#  'Captain America: Civil War',
#  'Doctor Strange',
#  'Guardians of the Galaxy Vol. 2',
#  'Spider-Man: Homecoming',
#  'Thor: Ragnarok',
#  'Black Panther',
#  'Avengers: Infinity War',
#  'Ant-Man and the Wasp',
#  'Captain Marvel',
#  'Avengers: End Game',
#  'Spider-Man: Far From Home',
#  'Black Widow',
#  'Shang-Chi and the Legend of the Ten Rings',
#  'Eternals',
#  'Spider-Man: No Way Home']

# %%
url = 'https://www.imdb.com/'

PATH=ChromeDriverManager().install()   # instala el driver
driver=webdriver.Chrome(PATH)         # abre una pestaña de chrome
driver.get(url)

# %%
buscador=driver.find_element(By.XPATH, '//*[@id="suggestion-search"]')

buscador.click()

# %%
buscador.send_keys(titulos[1])
time.sleep(2)
buscador.send_keys("\ue015")
time.sleep(2)
buscador.send_keys(u'\ue007')
time.sleep(2)

# %%
rating = driver.find_element(By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-9b716f3b-0.hWwhTB > section > div:nth-child(4) > section > section > div.sc-80d4314-0.fjPRnj > div.sc-db8c1937-0.eGmDjE.sc-80d4314-3.iBtAhY > div > div:nth-child(1) > a > div > div > div.sc-7ab21ed2-0.fAePGh > div.sc-7ab21ed2-2.kYEdvH > span.sc-7ab21ed2-1.jGRxWM')

# %%
rating.text
# Out:
# '6,6'

# %%
foto = driver.find_element(By.CLASS_NAME, 'ipc-lockup-overlay.ipc-focusable')

foto.get_attribute('href')
# Out:
# 'https://www.imdb.com/title/tt0800080/mediaviewer/rm2146527744/?ref_=tt_ov_i'

# %%
video = driver.find_element(By.CLASS_NAME, 'ipc-lockup-overlay.ipc-focusable')

video.get_attribute('href')
# Out:
# 'https://www.imdb.com/title/tt0800080/mediaviewer/rm2146527744/?ref_=tt_ov_i'

# %%
tab_reparto = driver.find_element(By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-9b716f3b-0.hWwhTB > div > section > div > div.sc-b1d8602f-1.fuYOtZ.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-bfec09a1-0.bzDutS.title-cast.title-cast--movie.celwidget > div.ipc-shoveler.ipc-shoveler--base.ipc-shoveler--page0.title-cast__grid > div.ipc-sub-grid.ipc-sub-grid--page-span-2.ipc-sub-grid--wraps-at-above-l.ipc-shoveler__grid')

# %%
tab_reparto
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b4c4da7d889c2018d8c59e4ce1baf2e7", element="e393914e-4e87-4bd1-ba24-67b32c50be62")>

# %%
reparto = tab_reparto.find_elements(By.CLASS_NAME, 'sc-bfec09a1-7.iDmJtd')

# %%
reparto[0].text.split('\n')
# Out:
# ['Edward Norton', 'Bruce Banner']

# %%
video = 'https://www.imdb.com/video/vi1726152985/?playlistId=tt0800080&ref_=tt_ov_vi'

# %%
lista_a  = []
for e in reparto:
    lista_a.append(dict((e.text.split('\n'),)))

# %%
# Out:
# [{'Edward Norton': 'Bruce Banner'},
#  {'Liv Tyler': 'Betty Ross'},
#  {'Tim Roth': 'Emil Blonsky'},
#  {'William Hurt': "General 'Thunderbolt' Ross"},
#  {'Tim Blake Nelson': 'Samuel Sterns'},
#  {'Ty Burrell': 'Leonard'},
#  {'Christina Cabot': 'Major Kathleen Sparr'},
#  {'Peter Mensah': 'General Joe Greller'},
#  {'Lou Ferrigno': 'Voice of The Incredible Hulk…'},
#  {'Paul Soles': 'Stanley'},
#  {'Débora Nascimento': 'Martina'},
#  {'Greg Bryk': 'Commando'},
#  {'Chris Owens': 'Commando'},
#  {'Al Vrkljan': 'Commando(as Alan Vrkljan)'},
#  {'Adrian Hein': 'Commando'},
#  {'John MacDonald': 'Commando'},
#  {'Shaun McComb': 'Helicopter Soldier'},
#  {'Simon Wong': 'Grad Student'}]

# %%
def scrap_imdb(lista_pelis):
    
    scrapeo_imdb = []
    pelis_noscrape = []
    
    url = 'https://www.imdb.com/'

    PATH=ChromeDriverManager().install()   # instala el driver
    driver=webdriver.Chrome(PATH)         # abre una pestaña de chrome
    driver.get(url)
    
    
    for peli in lista_pelis:
        
        try:
        
            datos_peli= [peli]
            buscador=driver.find_element(By.XPATH, '//*[@id="suggestion-search"]')
            buscador.click()

            buscador.send_keys(peli)
            time.sleep(3)
            buscador.send_keys("\ue015")
            time.sleep(3)
            buscador.send_keys(u'\ue007')
            time.sleep(3)

            rating = driver.find_element(By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-9b716f3b-0.hWwhTB > section > div:nth-child(4) > section > section > div.sc-80d4314-0.fjPRnj > div.sc-db8c1937-0.eGmDjE.sc-80d4314-3.iBtAhY > div > div:nth-child(1) > a > div > div > div.sc-7ab21ed2-0.fAePGh > div.sc-7ab21ed2-2.kYEdvH > span.sc-7ab21ed2-1.jGRxWM')
            datos_peli.append(rating.text)

            foto = driver.find_element(By.CLASS_NAME, 'ipc-lockup-overlay.ipc-focusable')
            foto_peli = foto.get_attribute('href')
            datos_peli.append(foto_peli)

            video = driver.find_element(By.CLASS_NAME, 'ipc-lockup-overlay.ipc-focusable')
            video_trailer = video.get_attribute('href')
            datos_peli.append(video_trailer)

            tab_reparto = driver.find_element(By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-9b716f3b-0.hWwhTB > div > section > div > div.sc-b1d8602f-1.fuYOtZ.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-bfec09a1-0.bzDutS.title-cast.title-cast--movie.celwidget > div.ipc-shoveler.ipc-shoveler--base.ipc-shoveler--page0.title-cast__grid > div.ipc-sub-grid.ipc-sub-grid--page-span-2.ipc-sub-grid--wraps-at-above-l.ipc-shoveler__grid')
            reparto = tab_reparto.find_elements(By.CLASS_NAME, 'sc-bfec09a1-7.iDmJtd')
            lista_reparto = [dict((e.text.split('\n'),)) for e in reparto]
            datos_peli.append(lista_reparto)
            scrapeo_imdb.append(datos_peli)
            
        except:
            
            pelis_noscrape.append(peli)
        
    driver.close()
        
    return scrapeo_imdb, pelis_noscrape

# %%
imdb = scrap_imdb(titulos)

# %%
imdb[0][0:2]
# Out:
# [['Iron Man',
#   '7,9',
#   'https://www.imdb.com/title/tt0371746/mediaviewer/rm1544850432/?ref_=tt_ov_i',
#   'https://www.imdb.com/title/tt0371746/mediaviewer/rm1544850432/?ref_=tt_ov_i',
#   [{'Robert Downey Jr.': 'Tony Stark'},
#    {'Gwyneth Paltrow': 'Pepper Potts'},
#    {'Terrence Howard': 'Rhodey'},
#    {'Jeff Bridges': 'Obadiah Stane'},
#    {'Leslie Bibb': 'Christine Everhart'},
#    {'Shaun Toub': 'Yinsen'},
#    {'Faran Tahir': 'Raza'},
#    {'Clark Gregg': 'Agent Coulson'},
#    {'Bill Smitrovich': 'General Gabriel'},
#    {'Sayed Badreya': 'Abu Bakaar'},
#    {'Paul Bettany': 'JARVIS(voz)'},
#    {'Jon Favreau': 'Hogan'},
#    {'Peter Billingsley': 'William Ginter Riva'},
#    {'Tim Guinee': 'Major Allen'},
#    {'Will Lyman': 'Award Ceremony Narrator(voz)'},
#    {'Tom Morello': 'Guard'},
#    {'Marco Khan': 'Guard'},
#    {'Dastan Khalili': 'Guard(as Daston Kalili)'}]],
#  ['The Incredible Hulk',
#   '6,6',
#   'https://www.imdb.com/title/tt0800080/mediaviewer/rm2146527744/?ref_=tt_ov_i',
#   'https://www.imdb.com/title/tt0800080/mediaviewer/rm2146527744/?ref_=tt_ov_i',
#   [{'Edward Norton': 'Bruce Banner'},
#    {'Liv Tyler': 'Betty Ross'},
#    {'Tim Roth': 'Emil Blonsky'},
#    {'William Hurt': "General 'Thunderbolt' Ross"},
#    {'Tim Blake Nelson': 'Samuel Sterns'},
#    {'Ty Burrell': 'Leonard'},
#    {'Christina Cabot': 'Major Kathleen Sparr'},
#    {'Peter Mensah': 'General Joe Greller'},
#    {'Lou Ferrigno': 'Voice of The Incredible Hulk'},
#    {'Paul Soles': 'Stanley'},
#    {'Débora Nascimento': 'Martina'},
#    {'Greg Bryk': 'Commando'},
#    {'Chris Owens': 'Commando'},
#    {'Al Vrkljan': 'Commando(as Alan Vrkljan)'},
#    {'Adrian Hein': 'Commando'},
#    {'John MacDonald': 'Commando'},
#    {'Shaun McComb': 'Helicopter Soldier'},
#    {'Simon Wong': 'Grad Student'}]]]

# %%
imdb[1]
# Out:
# ['Ant-Man', 'Ant-Man and the Wasp']

# %%
def scrap_imdb2(lista_pelis):
    
    scrapeo_imdb = []
    pelis_noscrape = []
    
    url = 'https://www.imdb.com/'

    PATH=ChromeDriverManager().install()   # instala el driver
    driver=webdriver.Chrome(PATH)         # abre una pestaña de chrome
    driver.get(url)
    
    
    for peli in lista_pelis:
        
        try:
        
            datos_peli= [peli]
            buscador=driver.find_element(By.XPATH, '//*[@id="suggestion-search"]')
            buscador.click()

            buscador.send_keys(peli)
            time.sleep(3)
            buscador.send_keys("\ue015")
            time.sleep(3)
            buscador.send_keys("\ue015")
            time.sleep(3)
            buscador.send_keys("\ue015")
            time.sleep(3)
            buscador.send_keys("\ue015")
            time.sleep(3)
            buscador.send_keys(u'\ue007')
            time.sleep(3)

            rating = driver.find_element(By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-9b716f3b-0.hWwhTB > section > div:nth-child(4) > section > section > div.sc-80d4314-0.fjPRnj > div.sc-db8c1937-0.eGmDjE.sc-80d4314-3.iBtAhY > div > div:nth-child(1) > a > div > div > div.sc-7ab21ed2-0.fAePGh > div.sc-7ab21ed2-2.kYEdvH > span.sc-7ab21ed2-1.jGRxWM')
            datos_peli.append(rating.text)

            foto = driver.find_element(By.CLASS_NAME, 'ipc-lockup-overlay.ipc-focusable')
            foto_peli = foto.get_attribute('href')
            datos_peli.append(foto_peli)

            video = driver.find_element(By.CLASS_NAME, 'ipc-lockup-overlay.ipc-focusable')
            video_trailer = video.get_attribute('href')
            datos_peli.append(video_trailer)

            tab_reparto = driver.find_element(By.CSS_SELECTOR, '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-9b716f3b-0.hWwhTB > div > section > div > div.sc-b1d8602f-1.fuYOtZ.ipc-page-grid__item.ipc-page-grid__item--span-2 > section.ipc-page-section.ipc-page-section--base.sc-bfec09a1-0.bzDutS.title-cast.title-cast--movie.celwidget > div.ipc-shoveler.ipc-shoveler--base.ipc-shoveler--page0.title-cast__grid > div.ipc-sub-grid.ipc-sub-grid--page-span-2.ipc-sub-grid--wraps-at-above-l.ipc-shoveler__grid')
            reparto = tab_reparto.find_elements(By.CLASS_NAME, 'sc-bfec09a1-7.iDmJtd')
            lista_reparto = [dict((e.text.split('\n'),)) for e in reparto]
            datos_peli.append(lista_reparto)
            scrapeo_imdb.append(datos_peli)
            
        except:
            
            pelis_noscrape.append(peli)
        
    driver.close()
        
    return scrapeo_imdb, pelis_noscrape

# %%
imdb2 = scrap_imdb2(imdb[1])

# %%
imdb2
# Out:
# ([['Ant-Man',
#    '7,3',
#    'https://www.imdb.com/title/tt0478970/mediaviewer/rm605716737/?ref_=tt_ov_i',
#    'https://www.imdb.com/title/tt0478970/mediaviewer/rm605716737/?ref_=tt_ov_i',
#    [{'Paul Rudd': 'Scott Lang…'},
#     {'Michael Douglas': 'Dr. Hank Pym'},
#     {'Corey Stoll': 'Darren Cross…'},
#     {'Evangeline Lilly': 'Hope Van Dyne'},
#     {'Bobby Cannavale': 'Paxton'},
#     {'Anthony Mackie': 'Sam Wilson…'},
#     {'Judy Greer': 'Maggie Lang'},
#     {'Abby Ryder Fortson': 'Cassie Lang'},
#     {'Michael Peña': 'Luis'},
#     {'David Dastmalchian': 'Kurt'},
#     {'T.I.': "Dave(as Tip 'T.I.' Harris)"},
#     {'Wood Harris': 'Gale'},
#     {'Hayley Atwell': 'Peggy Carter'},
#     {'John Slattery': 'Howard Stark'},
#     {'Martin Donovan': 'Mitchell Carson'},
#     {'Garrett Morris': 'Cab Driver'},
#     {'Gregg Turkington': 'Dale'},
#     {'Rod Hallett': 'Hydra Buyer'}]],
#   ['Ant-Man and the Wasp',
#    '7,0',
#    'https://www.imdb.com/title/tt5095030/mediaviewer/rm1698591232/?ref_=tt_ov_i',
#    'https://www.imdb.com/title/tt5095030/mediaviewer/rm1698591232/?ref_=tt_ov_i',
#    [{'Paul Rudd': 'Scott Lang…'},
#     {'Evangeline Lilly': 'Hope Van Dyne…'},
#     {'Michael Peña': 'Luis'},
#     {'Walton Goggins': 'Sonny Burch'},
#     {'Bobby Cannavale': 'Paxton'},
#     {'Judy Greer': 'Maggie'},
#     {'T.I.': "Dave(as Tip 'T.I.' Harris)"},
#     {'David Dastmalchian': 'Kurt'},
#     {'Hannah John-Kamen': 'Ava…'},
#     {'Abby Ryder Fortson': 'Cassie'},
#     {'Randall Park': 'Jimmy Woo'},
#     {'Michelle Pfeiffer': 'Janet Van Dyne…'},
#     {'Laurence Fishburne': 'Dr. Bill Foster'},
#     {'Michael Douglas': 'Dr. Hank Pym'},
#     {'Divian Ladwa': 'Uzman'},
#     {'Goran Kostic': 'Anitolov'},
#     {'Rob Archer': 'Knox'},
#     {'Sean Kleier': 'Agent Stoltz(as Sean Thompson Kleier)'}]]],
#  [])
